# %%
print('hi')
# Out:
# hi

# %%
import requests
from collections import defaultdict
import time

# %%
UNISWAP_V3_SUBGRAPH_URL = "https://gateway.thegraph.com/api/214ad8fea4f34456c35952f32963b967/subgraphs/id/5zvR82QoaXYFyDEKLZ9t6v9adgnptxYpKpSbxtgVENFV"

def fetch_october_2023_tokens_from_pools():
    query = """
    {
      pools(
        first: 1000,
        orderBy: createdAtTimestamp,
        orderDirection: asc,
        where: {
          createdAtTimestamp_gte: 1696118400,
          createdAtTimestamp_lt: 1698796800
        }
      ) {
        id
        createdAtTimestamp
        token0 {
          id
          symbol
          name
          decimals
        }
        token1 {
          id
          symbol
          name
          decimals
        }
      }
    }
    """

    response = requests.post(UNISWAP_V3_SUBGRAPH_URL, json={"query": query})
    data = response.json()

    if "errors" in data:
        print("GraphQL error:", data["errors"])
        return []

    tokens = {}
    for pool in data["data"]["pools"]:
        for token_key in ["token0", "token1"]:
            token = pool[token_key]
            tokens[token["id"]] = {
                "address": token["id"],
                "symbol": token["symbol"],
                "name": token["name"],
                "decimals": int(token["decimals"])
            }

    print(f"✅ Found {len(tokens)} unique ERC-20 tokens in pools created Oct 2023.")
    return list(tokens.values())

tokens_october = fetch_october_2023_tokens_from_pools()
# Out:
# ✅ Found 911 unique ERC-20 tokens in pools created Oct 2023.

# %%
symbols = sorted(set(token['symbol'] for token in tokens_october))
print(symbols)
# Out:
# ['', '#LINK', '$', '$DAWG', '$DORKM', '$EBT', '$Hiii', '$MOON', '$PAAL', '$REKT', '$WAGER', '$bRFD', '$hit', '$tunes', '( ͡° ͜ʖ ͡°)', '(WoW)', '-0-', '0xBTC', '0xETH', '0xFRIDAY', '0xUVSPERM', '0xb', '1024', '10X', '2', '401K', '4TOKEN', '7AΩ∞', '9INCH', 'ABE', 'ADAM', 'AGIX', 'AIGCFI', 'AIR', 'AKIT', 'ALLBI', 'ALLIES', 'ALPHAS', 'AMONG', 'AOKIJI', 'APE', 'APEMAX', 'APL', 'APU', 'ARAB', 'ARDVRK', 'ARMCP', 'ATACMS', 'ATI', 'AUDD', 'AUDITAI', 'AUSD', 'AVA', 'AVAX', 'AVI', 'AVID', 'AVO', 'AXL', 'AZUR', 'B3', 'BABY', 'BABYBIGTIME', 'BABYCAL', 'BABYETH', 'BABYPEPE', 'BAMF', 'BANK', 'BART', 'BBOT', 'BBX', 'BCAT', 'BDOGE', 'BEAN', 'BEBE', 'BEEF', 'BEES', 'BERK', 'BETA', 'BETA2', 'BIFI', 'BIGTIME', 'BITCOIN', 'BITCOIN6900', 'BITCOINCASH', 'BITROCK', 'BITTIES', 'BLAQ', 'BLID', 'BLOCK', 'BLOCKSKY', 'BLOX', 'BMX', 'BMXC', 'BOBA', 'BOBBY', 'BOI', 'BONE', 'BONZI', 'BOOTY', 'BOTTLENECK', 'BOX', 'BOY', 'BPD', 'BPEPE', 'BRK', 'BRK.A+B', 'BRNK', 'BRO', 'BS9000', 'BSMV', 'BTC', 'BTC 0.5', 'BTCETF', 'BTCINU', 'BTCX', 'BTKM', 'BTL', 'BTV', 'BUGMAN', 'BYTE', 'BZNA', 'BabyDoge', 'BabySHIB', 'BcGame', 'BitPEPE', 'Bitvm', 'Blinky', 'Bonk', 'C', 'C73', 'CAIN', 'CAKE', 'CAL', 'CAMEL', 'CARDANO', 'CAROLINE', 'CASH', 'CAT', 'CF', 'CFD', 'CGG', 'CHAD', 'CHAI', 'CHNGCBDC', 'CHUN', 'CIT', 'CMTL', 'CNV', 'COCK', 'COIN', 'COINRIG', 'CONAN', 'CONSPIRACY', 'CORGI', 'COUNT', 'CPP', 'CPRC', 'CPRX', 'CPTK', 'CRAMER', 'CRCLE', 'CRETH2', 'CRIMINGO', 'CRMNGO', 'CRYPTZY', 'CST', 'CUC', 'CULT', 'CWC', 'CZ', 'Cybersynapse', 'DAFFY', 'DAI', 'DAO9', 'DART', 'DDA', 'DEE', 'DEEP', 'DEFI', 'DERANGED', 'DFI', 'DFLX', 'DI', 'DICKI', 'DIP$ET', 'DND', 'DNT', 'DOG', 'DOGEFI', 'DOGEV3', 'DOGGY', 'DOLPHINU', 'DONUT', 'DOVU[eth]', 'DOX', 'DRAGON', 'DRIP', 'DRPEPE', 'DSH', 'DTC', 'Dickipedia', 'DogeOlio', 'Dogecommunity', 'Dragon', 'EAG', 'EAGLE', 'EDOGE', 'EGW', 'ELEPHANT', 'ELMAGA', 'ELON', 'ELONG', 'ELONGATE', 'EMPTY', 'END', 'ENTER', 'EPEPE', 'ERIC', 'ESL', 'ESY', 'ETF', 'ETH', 'ETHEREUM', 'ETHPM', 'ETHTC', 'ETHx', 'EVLN', 'Early', 'Elongat Elon Gate', 'FACKCointelegraph', 'FAFO', 'FCBI', 'FDAO', 'FDNZA', 'FDUSD', 'FEL', 'FGem', 'FINALE', 'FISH', 'FISHCOIN', 'FLC', 'FLOKI', 'FLUX', 'FNCT', 'FOXY', 'FREEW', 'FRP', 'FTCH', 'FTM', 'FTTX', 'FTX', 'FUJP', 'FWB', 'FWEN', 'FlokiDragon', 'G2', 'GAIDEN', 'GAMER', 'GANDALF', 'GAROC', 'GAZA', 'GBTC', 'GDIT', 'GEEK', 'GEFORCE', 'GEICO', 'GIB', 'GIMMEMONEY', 'GIMP', 'GLE', 'GLINK', 'GMLO', 'GOD', 'GOE', 'GOGETA', 'GOLD', 'GOLDEN', 'GOOVY', 'GORILLAZ', 'GPC', 'GRAI', 'GSHIB', 'GST1', 'GSWIFT', 'GTFO', 'GYATT', 'Gamer', 'Godzilla', 'H0X', 'HALLOWEEN', 'HAMA', 'HAMAZ', 'HAMS', 'HARAMBE', 'HAY', 'HAY2.0', 'HBST', 'HCN', 'HENLO', 'HGW', 'HODL', 'HODLMOON', 'HORK', 'HORROR', 'HOUR', 'HPW', 'HUM', 'HUSH', 'Hammer', 'Hawk', 'Hexy9', 'HoT', 'HulkDoge', 'I.C.C', 'IBTC', 'ICRC', 'IDEX', 'IFX', 'IKOLF-TEST-3', 'ILUM', 'INF', 'INJ', 'INST', 'IOC', 'ISR', 'ISRAEL', 'Illiterate', 'IsraelX', 'JACK', 'JARVIS', 'JASON', 'JCD', 'JEFE', 'JESUS', 'JEWS', 'JIZZ', 'JNB', 'JNE', 'JOANNA', 'JOE', 'JOEMAMA', 'JTEST', 'JUGGALO', 'JUM', 'Jammy', 'KAMEN', 'KAS', 'KEET', 'KEITH', 'KIM', 'KINGDOM', 'KIRBY', 'KIZU', 'KIZUNA', 'KL', 'KNGFU', 'KONG', 'KRBY', 'KRWT', 'KVT', 'Kekec', 'LAC', 'LAMBO', 'LAT', 'LBR', 'LDL', 'LDM', 'LINEA', 'LINK', 'LIQGROW', 'LISA1', 'LLIQ ', 'LLT', 'LMAO', 'LMI', 'LNA', 'LOK', 'LOOKS', 'LOOM', 'LOTC', 'LOTTE', 'LPBURN', 'LPR', 'LPX', 'LQINV', 'LTC', 'LUCK', 'LUNA', 'LXX', 'LYNX', 'Laugh', 'Lisa', 'MADA', 'MAKARONI', 'MAR', 'MASONS', 'MATIC', 'MATRIX', 'MAX', 'MAXIM', 'MBC', 'MBDZ', 'MCC', 'MDI', 'MDJRN', 'MDT', 'MEGA', 'MEK', 'MELIO', 'MEMU', 'MEOWL', 'META', 'METAIX', 'MEVT', 'MFYZ', 'MILEI', 'MINEP', 'MINT', 'MJC', 'MKR', 'MML', 'MMM6900', 'MMX', 'MNM', 'MOB', 'MONA', 'MONDAY', 'MONEY', 'MOON', 'MOONC', 'MOONS', 'MORAL', 'MPEPE', 'MPS', 'MSTR', 'MTV', 'MUFC', 'MXTK', 'MZM', 'MineLab', 'NAPOLEON', 'NASDAQ6900', 'NATI', 'NCC', 'NERD', 'NFAi', 'NFTC', 'NGUF', 'NLINK', 'NO 1 crypto investment', 'NODEV', 'NOFACE', 'NPEPE', 'NTDXZ', 'NTST', 'NVRME', ' ...

# %%
len(symbols)
# Out:
# 820

# %%
API_KEY = "214ad8fea4f34456c35952f32963b967"
HEADERS = {"Authorization": f"Bearer {API_KEY}"}
SUBGRAPH_URL = "https://gateway.thegraph.com/api/subgraphs/id/5zvR82QoaXYFyDEKLZ9t6v9adgnptxYpKpSbxtgVENFV"

# Unix timestamps for Oct 1 00:00:00 and Nov 1 00:00:00 UTC
START_TS = 1696118400  # Oct 1, 2023
END_TS = 1698796800    # Nov 1, 2023

def run_query(query):
    response = requests.post(SUBGRAPH_URL, json={"query": query}, headers=HEADERS)
    if response.status_code == 200:
        resp_json = response.json()
        if "errors" in resp_json:
            raise Exception(f"GraphQL errors: {resp_json['errors']}")
        return resp_json["data"]
    else:
        raise Exception(f"Query failed with status code {response.status_code}: {response.text}")

def fetch_pools_created_october():
    pools = []
    skip = 0
    batch_size = 1000

    while True:
        query = f"""
        {{
          pools(
            first: {batch_size},
            skip: {skip},
            orderBy: createdAtTimestamp,
            orderDirection: asc,
            where: {{
              createdAtTimestamp_gte: {START_TS},
              createdAtTimestamp_lt: {END_TS}
            }}
          ) {{
            id
            createdAtTimestamp
            token0 {{
              id
              symbol
              name
              decimals
            }}
            token1 {{
              id
              symbol
              name
              decimals
            }}
          }}
        }}
        """
        data = run_query(query)
        batch = data["pools"]
        pools.extend(batch)
        print(f"Fetched {len(batch)} pools, total so far: {len(pools)}")
        if len(batch) < batch_size:
            break
        skip += batch_size
        time.sleep(0.3)  # be gentle to API

    return pools

def extract_unique_tokens_from_pools(pools):
    tokens = {}
    for pool in pools:
        for token_key in ["token0", "token1"]:
            token = pool[token_key]
            tokens[token["id"]] = {
                "symbol": token["symbol"],
                "name": token["name"],
                "decimals": int(token["decimals"]),
                "address": token["id"],
            }
    return tokens

def fetch_pool_day_data(pool_ids):
    pool_volumes = defaultdict(float)
    batch_size = 50

    # Fetch daily volumes for each pool for October
    for i in range(0, len(pool_ids), batch_size):
        batch_ids = pool_ids[i : i + batch_size]
        ids_string = ','.join(f'"{pid}"' for pid in batch_ids)

        query = f"""
        {{
          poolDayDatas(
            where: {{
              pool_in: [{ids_string}],
              date_gte: {START_TS},
              date_lt: {END_TS}
            }},
            first: 1000
          ) {{
            pool {{
              id
              token0 {{
                id
                symbol
              }}
              token1 {{
                id
                symbol
              }}
            }}
            volumeUSD
            date
          }}
        }}
        """
        data = run_query(query)
        day_data = data["poolDayDatas"]

        for record in day_data:
            pool = record["pool"]
            vol = float(record["volumeUSD"])
            # Assign half volume to token0 and half to token1 (simplification)
            pool_volumes[pool["token0"]["id"]] += vol / 2
            pool_volumes[pool["token1"]["id"]] += vol / 2

        print(f"Processed batch {i} to {i+batch_size}, total poolDayData: {len(day_data)}")
        time.sleep(0.3)

    return pool_volumes

# %%
def main():
    print("Fetching pools created in October 2023...")
    pools = fetch_pools_created_october()
    print(f"Total pools fetched: {len(pools)}")

    print("Extracting unique tokens from pools...")
    tokens = extract_unique_tokens_from_pools(pools)
    print(f"Total unique tokens found: {len(tokens)}")

    pool_ids = [pool["id"] for pool in pools]
    print(f"Fetching poolDayData for {len(pool_ids)} pools...")

    volumes = fetch_pool_day_data(pool_ids)

# %%
def main():
    print("Fetching pools created in October 2023...")
    pools = fetch_pools_created_october()
    print(f"Total pools fetched: {len(pools)}")

    print("Extracting unique tokens from pools...")
    tokens = extract_unique_tokens_from_pools(pools)
    print(f"Total unique tokens found: {len(tokens)}")

    pool_ids = [pool["id"] for pool in pools]
    print(f"Fetching poolDayData for {len(pool_ids)} pools...")

    volumes = fetch_pool_day_data(pool_ids)
    print(f"Calculated monthly volumes for {len(volumes)} tokens.")

    # Sort tokens by volume descending
    sorted_tokens = sorted(volumes.items(), key=lambda x: x[1], reverse=True)

    print("\nTop 5 tokens by volume in October 2023:")
    for token_id, vol in sorted_tokens[:5]:
        symbol = tokens[token_id]["symbol"] if token_id in tokens else "UNKNOWN"
        print(f"{symbol} ({token_id}): ${vol:,.2f}")

    # Now slice tokens ranked 100 to 199 (0-based indexing)
    subset_tokens = sorted_tokens[100:200]

    print("\nTop 5 tokens by volume ranked 100-200:")
    for token_id, vol in subset_tokens[:5]:
        symbol = tokens[token_id]["symbol"] if token_id in tokens else "UNKNOWN"
        print(f"{symbol} ({token_id}): ${vol:,.2f}")

    # Now slice tokens ranked 50 to 99 (0-based indexing)
    subset_tokens = sorted_tokens[50:100]

    print("\nTop 5 tokens by volume ranked 50-100:")
    for token_id, vol in subset_tokens[:5]:
        symbol = tokens[token_id]["symbol"] if token_id in tokens else "UNKNOWN"
        print(f"{symbol} ({token_id}): ${vol:,.2f}")
        
        
    # Sort tokens by volume descending
    sorted_tokens = sorted(volumes.items(), key=lambda x: x[1], reverse=True)

    print("\nTop 20 tokens by volume in October 2023:")
    for token_id, vol in sorted_tokens[:20]:
        symbol = tokens[token_id]["symbol"] if token_id in tokens else "UNKNOWN"
        print(f"{symbol} ({token_id}): ${vol:,.2f}")


if __name__ == "__main__":
    main()
# Out:
# Fetching pools created in October 2023...
# Fetched 1000 pools, total so far: 1000
# Fetched 100 pools, total so far: 1100
# Total pools fetched: 1100
# Extracting unique tokens from pools...
# Total unique tokens found: 998
# Fetching poolDayData for 1100 pools...
# Processed batch 0 to 50, total poolDayData: 280
# Processed batch 50 to 100, total poolDayData: 384
# Processed batch 100 to 150, total poolDayData: 318
# Processed batch 150 to 200, total poolDayData: 161
# Processed batch 200 to 250, total poolDayData: 224
# Processed batch 250 to 300, total poolDayData: 140
# Processed batch 300 to 350, total poolDayData: 216
# Processed batch 350 to 400, total poolDayData: 226
# Processed batch 400 to 450, total poolDayData: 205
# Processed batch 450 to 500, total poolDayData: 205
# Processed batch 500 to 550, total poolDayData: 170
# Processed batch 550 to 600, total poolDayData: 213
# Processed batch 600 to 650, total poolDayData: 150
# Processed batch 650 to 700, total poolDayData: 186
# Processed batch 700 to 750, total poolDayData: 153
# Processed batch 750 to 800, total poolDayData: 141
# Processed batch 800 to 850, total poolDayData: 145
# Processed batch 850 to 900, total poolDayData: 126
# Processed batch 900 to 950, total poolDayData: 108
# Processed batch 950 to 1000, total poolDayData: 91
# Processed batch 1000 to 1050, total poolDayData: 66
# Processed batch 1050 to 1100, total poolDayData: 51
# Calculated monthly volumes for 998 tokens.
#
# Top 5 tokens by volume in October 2023:
# WETH (0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2): $219,521,604.36
# HAY (0xfa3e941d1f6b7b10ed84a0c211bfa8aee907965e): $45,778,164.52
# FLC (0x102c776ddb30c754ded4fdcc77a19230a60d4e4f): $19,873,082.05
# WBTC (0x2260fac5e5542a773aa44fbcfedf7c193bc2c599): $15,601,872.28
# crvUSD (0xf939e0a03fb07f59a73314e73794be0e57ac1b4e): $15,446,047.46
#
# Top 5 tokens by volume ranked 100-200:
# WiDra (0x7feafe97c37ab55565357da14d5706b6d88510b1): $309,217.45
# AOKIJI (0xf3490179394c67cec1d217eb3047ad8f738f635f): $308,875.98
# BIFI (0xb1f1ee126e9c96231cc3d3fad7c08b4cf873b1f1): $306,666.33
# TOONS (0x792833b894775bd769b3c602ba7172e59a83ab3f): $305,610.86
# μCaptainz (0xa100eafdef0099700933538ee795cfad5505b689): $304,800.10
#
# Top 5 tokens by volume ranked 50-100:
# MineLab (0x9cb00f90c22b2ac59d99544a92873cb76c22e561): $783,196.97
# VARK (0x66d4e39c355a911f6d19b3612785b63184a57c72): $774,506.68
# NNN (0x14106256ee14556ffe4109b7e71ed7dcdfb06746): $770,037.39
# μMAYC (0x359108ca299ca693502ef217e2109ad02aa4277c): $767,793.24
# BUGMAN (0x59c2ac218522ec689686f46eae1c6c998652cf80): $741,638.82
#
# Top 20 tokens by volume in October 2023:
# WETH (0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2): $219,521,604.36
# HAY (0xfa3e941d1f6b7b10ed84a0c211bfa8aee907965e): $45,778,164.52
# FLC (0x102c776ddb30c754ded4fdcc77a19230a60d4e4f): $19,873,082.05
# WBTC (0x2260fac5e5542a773aa44fbcfedf7c193bc2c599): $15,601,872.28
# crvUSD (0xf939e0a03fb07f59a73314e73794be0e57ac1b4e): $15,446,047.46
# TITANX (0xf19308f923582a6f7c465e5ce7a9dc1bec6665b1): $14,241,429.80
# μBAYC (0x1e610de0d7acfa1d820024948a91d96c5c9ce6b9): $14,106,483.16
# BIGTIME (0x64bc2ca1be492be7185faa2c8835d9b824c8a194): $11,188,511.17
# VOMBATUS (0x41b559d2854080646a0560b72c4be939e19dbf81): $9,698,422.36
# μPPG (0x30f7c830e0c2f4bec871df809d73e27ef19eb151): $5,769,380.80
# JOE (0x76e222b07c53d28b89b0bac18602810fc22b49a8): $4,861,865.13
# USDT (0xdac17f958d2ee523a2206206994597c13d831ec7): $3,977,903.03
# SAFEREUM (0xb504035a11e672e12a099f32b1672b9c4a78b22f): $3,958,350.05
# REFUND (0x415ff1afc201eec50beff210a2f456674046920b): $3,750,418.25
# FWEN (0x822d9647ff6d028915dc9040e4ae54565eaf788c): $3,069,546.99
# KIZUNA (0x470c8950c0c3aa4b09654bc73b004615119a44b5): $2,842,622.60
# TIME (0xef89c37fe9e5c906b404cd7edae4a2992b5d25fa): $2,451,385.95
# μy00t (0xec19caef9c046f5f87a497154766742ab9c90820): $2,430,859.23
# SCHAP (0x3638c9e50437f00ae53a649697f288ba68888cc1): $2,188,869.24
# $REKT (0x4f8b986ecffe7bed5dbeb2b49310fb00ca85a539): $1,956,267.15
